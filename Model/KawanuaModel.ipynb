# %%
# !wget --no-check-certificate \
  https://github.com/Kawanua-project/KawanuaML/archive/main.zip \
  -O /tmp/KawanuaML.zip
# Out:
# --2023-12-06 15:12:29--  https://github.com/Kawanua-project/KawanuaML/archive/main.zip
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/Kawanua-project/KawanuaML/zip/refs/heads/main [following]
# --2023-12-06 15:12:29--  https://codeload.github.com/Kawanua-project/KawanuaML/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 20.29.134.24
# Connecting to codeload.github.com (codeload.github.com)|20.29.134.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘/tmp/KawanuaML.zip’
#
# /tmp/KawanuaML.zip      [            <=>     ] 159.39M  20.8MB/s    in 7.1s
#
# 2023-12-06 15:12:36 (22.6 MB/s) - ‘/tmp/KawanuaML.zip’ saved [167130398]

# %%
# !unzip /tmp/KawanuaML.zip -d /tmp && rm /tmp/KawanuaML.zip
# Out:
# Archive:  /tmp/KawanuaML.zip
# 6a7a85bb2468b53052d198c20d60e1bef187685d
#    creating: /tmp/KawanuaML-main/
#    creating: /tmp/KawanuaML-main/Datasets/
#    creating: /tmp/KawanuaML-main/Datasets/Hewan/
#    creating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/04e5ec1e-ebcb-4f34-a411-5ea64d14e79b.jpg
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/08477fb0-3509-432f-a533-870ac05af201.jpg
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/0ac1a37b-455d-4910-9e1c-803b16882c82.JPEG
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/0b7704ef-057a-4ab3-980e-52ce9eb6774d.jpg
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/0d899913-3f98-49a3-83d4-fa957144e694.JPEG
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/0e0d524e-0261-41f7-a8d3-f65b5ad7abbd.JPEG
#   inflating: /tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/0f09217d-945d-4e91-9e82-3e6dc3f105eb.JPEG
# ...

# %%
#Install split folders
# !pip install split_folders

# %%
# Import library yang diperlukan
import splitfolders as sf
import os

# Path awal dataset
base_dir = '/tmp/KawanuaML-main/Datasets/Hewan'

# Path untuk menyimpan dataset yang telah dibagi
output_dir = '/tmp/KawanuaML-main/image'

# Memastikan direktori output ada atau belum, jika belum, buat direktori
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Menggunakan split-folders untuk membagi dataset menjadi train dan validation set
sf.ratio(
    input=base_dir,
    output=output_dir,
    seed=None,
    ratio=(0.6, 0.4),
    group_prefix=None  # Tidak menggunakan grouping
)
# Out:
# Copying files: 760 files [00:00, 4509.29 files/s]

# %%
# Import library yang diperlukan
import splitfolders as sf
import os

# Path awal dataset
base_dir = '/tmp/KawanuaML-main/Datasets/Tumbuhan'

# Path untuk menyimpan dataset yang telah dibagi
output_dir = '/tmp/KawanuaML-main/image'

# Memastikan direktori output ada atau belum, jika belum, buat direktori
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Menggunakan split-folders untuk membagi dataset menjadi train dan validation set
sf.ratio(
    input=base_dir,
    output=output_dir,
    seed=None,
    ratio=(0.6, 0.4),
    group_prefix=None  # Tidak menggunakan grouping
)
# Out:
# Copying files: 760 files [00:00, 1828.77 files/s]

# %%
# Mengatur direktori train dan validation untuk masing-masing kategori
image_dir = '/tmp/KawanuaML-main/image'

train_AnaphalisJavanica_dir  = os.path.join(image_dir, 'train/Anaphalis javanica')
train_GajahAsia_dir      = os.path.join(image_dir, 'train/GajahAsia')
train_Orangutan_dir      = os.path.join(image_dir, 'train/Orangutan')
train_RafflesiaArnoldii_dir = os.path.join(image_dir, 'train/Rafflesia arnoldii')

validation_AnaphalisJavanica_dir = os.path.join(image_dir, 'val/Anaphalis javanica')
validation_GajahAsia_dir = os.path.join(image_dir, 'val/GajahAsia')
validation_Orangutan_dir = os.path.join(image_dir, 'val/Orangutan')
validation_RafflesiaArnoldii_dir = os.path.join(image_dir, 'val/Rafflesia arnoldii')

# %%
# Menghitung jumlah gambar pada set pelatihan untuk setiap kategori
train_set_AnaphalisJavanica  = len(os.listdir(train_AnaphalisJavanica_dir))
train_set_GajahAsia         = len(os.listdir(train_GajahAsia_dir))
train_set_Orangutan          = len(os.listdir(train_Orangutan_dir))
train_set_RafflesiaArnoldii  = len(os.listdir(train_RafflesiaArnoldii_dir))

# Menghitung jumlah gambar pada set validasi untuk setiap kategori
validation_set_AnaphalisJavanica  = len(os.listdir(train_AnaphalisJavanica_dir))
validation_set_GajahAsia          = len(os.listdir(train_GajahAsia_dir))
validation_set_Orangutan        = len(os.listdir(train_Orangutan_dir))
validation_set_RafflesiaArnoldii  = len(os.listdir(train_RafflesiaArnoldii_dir))

# Menjumlahkan total gambar pada set pelatihan dan validasi
total_train_set = train_set_AnaphalisJavanica + train_set_GajahAsia + train_set_Orangutan + train_set_RafflesiaArnoldii
total_validation_set = validation_set_AnaphalisJavanica + validation_set_GajahAsia + validation_set_Orangutan + validation_set_RafflesiaArnoldii

# Menampilkan hasil
print(f'Total Train Set      : {total_train_set}')
print(f'Total Validation Set : {total_validation_set}')
print(f'Total Train Set Anaphalis Javanica : {train_set_AnaphalisJavanica}')
print(f'Total Train Set Rafflesia Arnoldii : {train_set_RafflesiaArnoldii}')
print(f'Total Train Set Orangutan : {train_set_Orangutan}')
print(f'Total Train Set Asian Elephant : {train_set_GajahAsia}')
print(f'Total Validation Set Anaphalis Javanica : {validation_set_AnaphalisJavanica}')
print(f'Total Validation Set Rafflesia Arnoldii : {validation_set_RafflesiaArnoldii}')
print(f'Total Validation Set Orangutan : {validation_set_Orangutan}')
print(f'Total Validation Set Asian Elephant : {validation_set_GajahAsia}')
# Out:
# Total Train Set      : 912
# Total Validation Set : 912
# Total Train Set Anaphalis Javanica : 228
# Total Train Set Rafflesia Arnoldii : 228
# Total Train Set Orangutan : 228
# Total Train Set Asian Elephant : 228
# Total Validation Set Anaphalis Javanica : 228
# Total Validation Set Rafflesia Arnoldii : 228
# Total Validation Set Orangutan : 228
# Total Validation Set Asian Elephant : 228

# %%
train_dir      = os.path.join(image_dir, 'train')
validation_dir = os.path.join(image_dir, 'val')

print(os.listdir(train_dir))
print(os.listdir(validation_dir))
# Out:
# ['Rafflesia arnoldii', 'Anaphalis javanica', 'GajahAsia', 'Orangutan']
# ['Rafflesia arnoldii', 'Anaphalis javanica', 'GajahAsia', 'Orangutan']

# %%
# !rm -rf /tmp/KawanuaML-main/Datasets/Hewan/.ipynb_checkpoints
# !rm -rf /tmp/KawanuaML-main/Datasets/Tumbuhan/.ipynb_checkpoints

# %%
from keras.preprocessing.image import ImageDataGenerator

# Augmentasi gambar pada set pelatihan
train_datagen = ImageDataGenerator(
    rescale=1./255,         # Normalisasi piksel
    rotation_range=20,      # Rentang rotasi gambar
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,   # Flip horizontal gambar
    shear_range=0.2,        # Efek shear
    zoom_range=0.2,
)

# Normalisasi gambar pada set validasi (tanpa augmentasi)
test_datagen = ImageDataGenerator(
    rescale=1./255  # Normalisasi piksel
)

# %%
# Persiapkan generator untuk set pelatihan
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(200, 200),   # Ukuran target gambar
    batch_size=32,           # Ukuran batch
    class_mode='categorical', # Mode kelas kategori
    shuffle=True             # Pengacakan data setiap epoch
)

# Persiapkan generator untuk set validasi
validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=(200, 200),   # Ukuran target gambar
    batch_size=32,           # Ukuran batch
    class_mode='categorical', # Mode kelas kategori
    shuffle=True             # Pengacakan data setiap epoch
)
# Out:
# Found 912 images belonging to 4 classes.
# Found 608 images belonging to 4 classes.

# %%
#membuat model
from keras import layers, Sequential
from keras.models import Model
from keras.layers import Conv2D, Activation, MaxPooling2D, Dropout, Flatten, Dense

# %%
import tensorflow as tf

# Membangun model Convolutional Neural Network (CNN) dengan MaxPooling
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(200, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.25),  # Menggunakan dropout untuk mengurangi overfitting
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Empat kelas, fungsi aktivasi softmax
])

# Menampilkan ringkasan model
model.summary()

# Kompilasi model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_11 (Conv2D)          (None, 198, 198, 32)      896
#
#  max_pooling2d_11 (MaxPooli  (None, 99, 99, 32)        0
#  ng2D)
#
#  conv2d_12 (Conv2D)          (None, 97, 97, 64)        18496
#
#  max_pooling2d_12 (MaxPooli  (None, 48, 48, 64)        0
#  ng2D)
#
#  conv2d_13 (Conv2D)          (None, 46, 46, 128)       73856
#
#  max_pooling2d_13 (MaxPooli  (None, 23, 23, 128)       0
#  ng2D)
#
#  conv2d_14 (Conv2D)          (None, 21, 21, 256)       295168
#
#  max_pooling2d_14 (MaxPooli  (None, 10, 10, 256)       0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 25600)             0
#
#  dropout_3 (Dropout)         (None, 25600)             0
#
#  dense_6 (Dense)             (None, 256)               6553856
#
#  dense_7 (Dense)             (None, 4)                 1028
#
# ...
# Total params: 6943300 (26.49 MB)
# ...

# %%
# Memuat ekstensi TensorBoard
# %load_ext tensorboard

# Membuat direktori log TensorBoard berdasarkan timestamp
import datetime, os
logdir = os.path.join('/content/sample_data', datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))

# Callback TensorBoard
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# Melatih model menggunakan model.fit()
history = model.fit(
    train_generator,
    steps_per_epoch=20,               # Jumlah langkah per epoch
    epochs=20,                        # Jumlah epoch pelatihan
    validation_data=validation_generator,
    validation_steps=5,               # Jumlah langkah validasi per epoch
    callbacks=[tensorboard_callback]  # Menambahkan callback TensorBoard
)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 90s 4s/step - loss: 1.3318 - accuracy: 0.3622 - val_loss: 0.8927 - val_accuracy: 0.5625
# Epoch 2/20
# 20/20 [==============================] - 94s 5s/step - loss: 0.8611 - accuracy: 0.6344 - val_loss: 0.7365 - val_accuracy: 0.7312
# Epoch 3/20
# 20/20 [==============================] - 84s 4s/step - loss: 0.7552 - accuracy: 0.6984 - val_loss: 0.6361 - val_accuracy: 0.7937
# Epoch 4/20
# 20/20 [==============================] - 88s 4s/step - loss: 0.7050 - accuracy: 0.7244 - val_loss: 0.7661 - val_accuracy: 0.7188
# Epoch 5/20
# 20/20 [==============================] - 88s 4s/step - loss: 0.6203 - accuracy: 0.7875 - val_loss: 0.7240 - val_accuracy: 0.7563
# Epoch 6/20
# 20/20 [==============================] - 85s 4s/step - loss: 0.5747 - accuracy: 0.8029 - val_loss: 0.3545 - val_accuracy: 0.9125
# Epoch 7/20
# ...

# %%
# Visualize accuracy and loss plot
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

accuracy     = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss         = history.history['loss']
val_loss     = history.history['val_loss']

epoch        = 20
epoch_range  = range(epoch)

plt.figure(figsize = (12, 4))
plt.subplot(1, 2, 1)
plt.plot(epoch_range, accuracy, label='Training Accuracy')
plt.plot(epoch_range, val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(epoch_range, loss,     label='Training Loss')
plt.plot(epoch_range, val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np
from keras.preprocessing import image

# Load and preprocess the input image
img_path = '/tmp/KawanuaML-main/Datasets/Hewan/GajahAsia/0f09217d-945d-4e91-9e82-3e6dc3f105eb.JPEG'
img = image.load_img(img_path, target_size = (200, 200,3))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalize the pixel values


# Make the prediction
labels = ['Anaphalis javanica',
          'Gajah Asia',
          'Orangutan',
          'Rafflesia arnoldii']
prediction = model.predict(img_array)
index = np.argmax(prediction)
class_names = labels[index]


# Get the predicted class label
predicted_class = class_names

# Print the predicted class label
print(f"Predicted Class: {predicted_class}")
# Out:
# 1/1 [==============================] - 0s 50ms/step
# Predicted Class: Gajah Asia

# %%
model.save("/tmp/KawanuaML-main/KawanuaModel.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
